# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
# %matplotlib inline
plt.style.use('seaborn-whitegrid')
#plt.style.use('classic')
#plt.style.use('seaborn-whitegrid')

# %%
print(plt.rcParams.get('figure.figsize'))
# Out:
# [6.0, 4.0]

# %%
# Set default size
plt.rcParams["figure.figsize"] = (6,4)

# %% [markdown]
# ## Load the data

# %%
jb1 = pd.read_csv('jelly-beans/jelly-beans.csv')

# %%
jb1.style.bar()

# %%
# Standard deviation
print('Standard deviation:', jb1.std().to_string(index=False))

f'jb2: {int(jb2.std())}'

# %%
print('Average:',jb1.mean().to_string(index=False))

# %%
print('Min: {}'.format(int(jb1.min())))
print('Max: {}'.format(int(jb1.max())))

# %%
print('Median:',jb1.median().to_string(index=False))

# %% [markdown]
# ## Seaborn

# %%
import seaborn as sns
sns.set_style('whitegrid')

# %%
# Which data to use
jbs = jb1.copy()

# %%
sns.histplot(data=jbs)
sns.despine()

# %%
sns.boxplot(x=None, y=None, data=jbs)
sns.despine()

# %%
# Scatter plot
sns.scatterplot(data=jbs)
sns.despine()

# %%
sns.stripplot(data=jbs)
sns.despine()

# %%
sns.kdeplot(data=jbs)
sns.despine()
