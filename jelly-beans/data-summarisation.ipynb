# %% [markdown]
# # Data Summarisation<img src='../header.png' alt='Jupyter Python NumPy Pandas Matplotlib' align='right' width='50%'></img>
# ### _Turning a large list of numbers into a single value_
# #### Presented by Ian Barbour - 4th January 2021
# <hr>
# <a href="../introduction-to-pandas.ipynb"><< Introduction to pandas</a>
# <span style="float:right;">
#     <a href="./data-aggregation.ipynb">Data Aggregation >></a>
# </span>

# %% [markdown]
# ### Python libraries:

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# ### Matplotlib settings:

# %%
# %matplotlib inline
plt.rc('xtick', labelsize=14)
plt.rc('ytick', labelsize=14)
plt.style.use('seaborn-whitegrid')

# %% [markdown]
# ### Open the csv file:

# %%
jb1 = pd.read_csv('jelly-beans.csv')

# %% [markdown]
# ### Display the data:

# %%
jb1
# Out:
#      guess
# 0      553
# 1      756
# 2     1860
# 3     1500
# 4      692
# ..     ...
# 678   1197
# 679   9000
# 680   2097
# 681   2466
# 682   1749
#
# [683 rows x 1 columns]

# %%
jb1.head()
# Out:
#    guess
# 0    553
# 1    756
# 2   1860
# 3   1500
# 4    692

# %%
jb1.tail()
# Out:
#      guess
# 678   1197
# 679   9000
# 680   2097
# 681   2466
# 682   1749

# %%
jb1.shape
# Out:
# (683, 1)

# %%
jb1.columns
# Out:
# Index(['guess'], dtype='object')

# %%
jb1['guess']
# Out:
# 0       553
# 1       756
# 2      1860
# 3      1500
# 4       692
#        ...
# 678    1197
# 679    9000
# 680    2097
# 681    2466
# 682    1749
# Name: guess, Length: 683, dtype: int64

# %% [markdown]
# ### Plot the data:

# %%
# Plot
plt.plot(jb1)
plt.show()

# %%
# Dot plot
plt.plot(jb1, 'bo')
plt.show()

# %%
# Increase the size of the graph
plt.figure(figsize=(20,10))
plt.plot(jb1, 'bo')
plt.show()

# %%
# Sorting the data may help
jbs = jb1.sort_values(by=['guess'], ignore_index=True)

plt.figure(figsize=(20,8))
plt.plot(jbs, 'bo')
plt.show()

# %%
# Box plot
plt.figure(figsize=(6,8))
plt.boxplot(jb1)
plt.show()

# %%
# Use help if you are not sure what a graph shows
# ?plt.boxplot

# %%
# Histogram
plt.hist(jb1)
plt.show()

# %%
# Histogram with more 'bins'
plt.hist(jb1, bins=30)
plt.show()

# %%
# Histogram with title and labels
plt.title('Guesses of number of jelly beans in the jar')
plt.xlabel('Number Guessed')
plt.ylabel('Count')
plt.hist(jb1, bins=50, color='blue', edgecolor='black')
plt.show()

# %% [markdown]
# ### Describe the data:

# %%
jb1.describe()
# Out:
#               guess
# count    683.000000
# mean    2263.330893
# std     2370.054045
# min       10.000000
# 25%     1122.000000
# 50%     1738.000000
# 75%     2551.000000
# max    31337.000000

# %% [markdown]
# ### We could filter out the outliers:

# %%
# guess >= 400 and guess < 9000
jb2 = jb1.loc[(jb1['guess'] >= 400) & (jb1['guess'] < 9000)]

# %%
# Dot plot
plt.figure(figsize=(20,10))
plt.plot(jb2, 'bo')
plt.show()

# %%
# Box plot - with filtered data
plt.figure(figsize=(6,8))
plt.boxplot(jb2)
plt.show()

# %%
plt.hist(jb2, bins=20, color='blue', edgecolor='black')
plt.show()

# %%
jb2.describe()
# Out:
#              guess
# count   659.000000
# mean   2072.220030
# std    1359.440227
# min     400.000000
# 25%    1152.000000
# 50%    1738.000000
# 75%    2537.000000
# max    8569.000000

# %%
# Difference in standard deviation
print('jb1: %.2f' % float(jb1.std()))
print('jb2: %.2f' % float(jb2.std()))
# Out:
# jb1: 2370.05
# jb2: 1359.44

# %% [markdown]
# ### Or we could convert the data to a logorithmic scale:

# %%
jb3 = np.log10(jb1)

# %%
jb3.head()
# Out:
#       guess
# 0  2.742725
# 1  2.878522
# 2  3.269513
# 3  3.176091
# 4  2.840106

# %%
# Dot plot
plt.figure(figsize=(20,8))
plt.plot(jb3, 'bo')
plt.show()

# %%
# 10 to the power of 3.5
pow(10,3.5)
# Out:
# 3162.2776601683795

# %%
# Bell curve
ax = jb3.plot.kde()
plt.show()

# %% [markdown]
# ### Spread of a data distribution
# #### Before we decide on a single number we should look at the variability (spread) of the data:

# %%
jb1.describe()
# Out:
#               guess
# count    683.000000
# mean    2263.330893
# std     2370.054045
# min       10.000000
# 25%     1122.000000
# 50%     1738.000000
# 75%     2551.000000
# max    31337.000000

# %%
# Range
print('Min: %d' % int(jb1.min()))
print('Max: %d' % int(jb1.max()))
# Out:
# Min: 10
# Max: 31337

# %%
# Average (mean)
print('Average: %.1f' % float(jb1.mean()))
# Out:
# Average: 2263.3

# %%
# Geometric Mean (median) [may be better due to large outliers]
print('Median: %.1f' % float(jb1.median()))
# Out:
# Median: 1738.0

# %%
# Mode [most common guess]
print('Mode: %s' % jb1.mode().to_string(index=False,header=False))
# Out:
# Mode:  1337

# %%
# Inter-quartile range (quantile 25 to 75) [the box in the box plot]
print('25th: %.0f' % float(jb1.quantile(0.25)))
print('75th: %.0f' % float(jb1.quantile(0.75)))
# Out:
# 25th: 1122
# 75th: 2551

# %% [markdown]
# ---
# End of: <a href="data-summarisation.ipynb">Data Summarisation</a>
# <span style="float:right;">
#     <a href="./data-aggregation.ipynb">Data Aggregation >></a>
# </span>
