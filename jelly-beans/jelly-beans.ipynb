# %% [markdown]
# # _Vox Populi_ ~ The Wisom of Crowds

# %% [markdown]
# ### Python libraries:

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import seaborn as sns

from matplotlib import pyplot as plt

# %%
#%matplotlib inline
#plt.style.use('classic')
#plt.style.use('seaborn-whitegrid')

# %% [markdown]
# ### Open the csv file:

# %%
jb1 = pd.read_csv('jelly-beans.csv')

# %%
jb1
# Out:
#      guess
# 0      553
# 1      756
# 2     1860
# 3     1500
# 4      692
# ..     ...
# 683   1197
# 684   9000
# 685   2097
# 686   2466
# 687   1749
#
# [688 rows x 1 columns]

# %%
jb1.head()
# Out:
#    guess
# 0    553
# 1    756
# 2   1860
# 3   1500
# 4    692

# %%
jb1.tail()
# Out:
#      guess
# 683   1197
# 684   9000
# 685   2097
# 686   2466
# 687   1749

# %%
jb1.shape
# Out:
# (688, 1)

# %%
jb1.columns
# Out:
# Index(['guess'], dtype='object')

# %%
jb1['guess']
# Out:
# 0       553
# 1       756
# 2      1860
# 3      1500
# 4       692
#        ...
# 683    1197
# 684    9000
# 685    2097
# 686    2466
# 687    1749
# Name: guess, Length: 688, dtype: int64

# %%
# Plot
plt.plot(jb1)
plt.show()

# %%
# Dot plot
plt.plot(jb1, 'bo')
plt.show()

# %%
# Box plot
plt.boxplot(jb1)
plt.show()

# %%
# Histogram
plt.hist(jb1)
plt.show()

# %%
# Histogram
plt.hist(jb1, bins=30)
plt.show()

# %%
jb1.describe()
# Out:
#               guess
# count    688.000000
# mean    2258.626453
# std     2362.054614
# min       10.000000
# 25%     1123.000000
# 50%     1731.000000
# 75%     2547.500000
# max    31337.000000

# %% [markdown]
# ### We could filter out the outliers:

# %%
# guess >= 400 and guess < 9000
jb2 = jb1.loc[(jb1['guess'] >= 0) & (jb1['guess'] < 5000)]

# %%
# Dot plot
plt.plot(jb2, 'bo')
plt.show()

# %%
plt.boxplot(jb2)
plt.show()

# %%
jb2.describe()
# Out:
#              guess
# count   645.000000
# mean   1833.865116
# std    1006.986016
# min      10.000000
# 25%    1054.000000
# 50%    1631.000000
# 75%    2383.000000
# max    4952.000000

# %%
plt.hist(jb2, bins=20)
plt.show()

# %% [markdown]
# ### Or we could convert the data to a logorithmic scale:

# %%
jb3 = np.log10(jb1)

# %%
jb3.head()
# Out:
#       guess
# 0  2.742725
# 1  2.878522
# 2  3.269513
# 3  3.176091
# 4  2.840106

# %%
# Dot plot
plt.plot(jb3, 'bo')
plt.show()

# %%
pow(10,3.5)
# Out:
# 3162.2776601683795

# %%
# Histogram
plt.hist(jb3, bins=25)
plt.show()

# %% [markdown]
# ## Seaborn

# %%
# Which data to use
jbs = jb1

# %%
sns.histplot(data=jbs)
sns.despine()

# %%
sns.boxplot(x=None, y=None, data=jbs)
sns.despine()

# %%
# Scatter plot
sns.scatterplot(data=jbs)
sns.despine()

# %%
sns.stripplot(data=jbs)
sns.despine()
